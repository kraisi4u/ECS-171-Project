# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 25 ,1)
acc = [0.7778, 0.9264, 0.9476, 0.9608, 0.9729, 0.9847, 0.9843, 0.9796, 0.9868, 0.9832, 0.9878, 0.9828, 0.9791, 0.9938, 0.9887, 0.9873, 0.9934, 0.9980, 0.9902, 0.9953, 0.9945, 0.9981, 0.9928, 0.9931, 0.9953]
val_acc = [0.4880, 0.4880, 0.5850, 0.9665, 0.9438, 0.9605, 0.9284, 0.9652, 0.9170, 0.9652, 0.9639, 0.9672, 0.9712, 0.8106, 0.8963, 0.9813, 0.9806, 0.9853, 0.8581, 0.9746, 0.9719, 0.9652, 0.9471, 0.9806, 0.9632]

plt.scatter(x, acc, label='train')
plt.scatter(x, val_acc, label='validate')

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
loss = [0.4522, 0.1793, 0.1233, 0.0906, 0.0707, 0.0426, 0.0433, 0.0501, 0.0368, 0.0358, 0.0345, 0.0371, 0.0497, 0.0179, 0.0278, 0.0316, 0.0198, 0.0073, 0.0264, 0.0157, 0.0136, 0.0068, 0.0201, 0.0178, 0.0128]
val_loss = [0.6975, 0.6939, 0.6377, 0.1400, 0.1093, 0.0994, 0.2026, 0.1140, 0.2031, 0.0874, 0.0869, 0.0901, 0.0833, 0.4027, 0.2436, 0.0569, 0.0651, 0.0419, 0.3214, 0.0628, 0.1112, 0.1011, 0.1337, 0.0446, 0.1023]

plt.scatter(x, loss, label='train')
plt.scatter(x, val_loss, label='validate')

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
